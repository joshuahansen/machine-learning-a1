# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


training_data = pd.read_csv('datafiles/train.csv', delimiter=',')
print(training_data)
# Out:
#         id  avgAnnCount  avgDeathsPerYear  incidenceRate     medIncome  \
# 0        1  1473.739001         26.486869     440.144020  67283.171774
# 1        2    49.220884         18.475044     492.156108  54561.671635
# 2        3   100.889361         49.277660     435.099883  45247.410703
# 3        4    73.988011         30.916075     366.261323  52904.399642
# 4        5   990.298447        354.609416     475.799083  61875.042840
# 5        6  1962.667684          5.882440     453.549422  52166.628189
# 6        7   177.440564         92.099554     506.596954  26374.601786
# 7        8    66.348279         33.278623     419.621458  37479.273012
# 8        9   162.117419         63.058709     432.818987  50166.138855
# 9       10    98.925661         43.099119     459.867951  38517.991191
# 10      11  2700.375383       1114.100377     477.632754  49973.499525
# 11      12    94.911853         38.202128     449.341797  73682.252749
# ...

# %%
testing_data = pd.read_csv('datafiles/test.csv', delimiter=',')
print(testing_data)
# Out:
#         id  avgAnnCount  avgDeathsPerYear  incidenceRate     medIncome  \
# 0     5018    31.802654         15.600885     370.270535  37313.812149
# 1     5019   110.434272         50.347753     438.628113  33344.349548
# 2     5020   863.140876        332.115577     459.194611  59609.484018
# 3     5021  1407.471385        577.030626     401.330097  51455.093904
# 4     5022   138.031694         63.849513     456.727128  33306.695269
# 5     5023   465.881075        195.036711     469.280610  45383.440311
# 6     5024    91.395641         39.798547     435.110681  38481.400736
# 7     5025   102.953616         49.386961     358.364281  49302.158324
# 8     5026    17.318807          7.772936     354.330045  56125.603209
# 9     5027   402.322299        176.624931     438.419958  34403.243360
# 10    5028  3997.360880       1437.233589     449.466771  71918.072763
# 11    5029   419.647003        153.943975     446.935983  43788.092237
# ...

# %%
pd.DataFrame.max(training_data)
# Out:
# id                         5.017000e+03
# avgAnnCount                3.815000e+04
# avgDeathsPerYear           1.401000e+04
# incidenceRate              1.206900e+03
# medIncome                  1.256350e+05
# popEst2015                 1.017029e+07
# povertyPercent             4.690000e+01
# studyPerCap                9.762309e+03
# MedianAge                  5.900000e+01
# MedianAgeMale              6.020000e+01
# MedianAgeFemale            5.870000e+01
# AvgHouseholdSize           3.970000e+00
# PercentMarried             7.250000e+01
# PctNoHS18_24               6.410000e+01
# PctHS18_24                 7.210000e+01
# PctSomeCol18_24            7.900000e+01
# PctBachDeg18_24            5.180000e+01
# PctHS25_Over               5.297228e+01
# PctBachDeg25_Over          4.220000e+01
# PctEmployed16_Over         8.010000e+01
# PctUnemployed16_Over       2.700000e+01
# PctPrivateCoverage         9.230000e+01
# PctPrivateCoverageAlone    7.820000e+01
# ...

# %%
pd.DataFrame.min(training_data)
# Out:
# id                             1.000000
# avgAnnCount                    6.000000
# avgDeathsPerYear               3.000000
# incidenceRate                201.300000
# medIncome                  22640.000000
# popEst2015                   829.000000
# povertyPercent                 3.200000
# studyPerCap                    0.000000
# MedianAge                     22.300000
# MedianAgeMale                 22.400000
# MedianAgeFemale               22.300000
# AvgHouseholdSize               0.022200
# PercentMarried                23.100000
# PctNoHS18_24                   0.000000
# PctHS18_24                     0.081874
# PctSomeCol18_24                7.100000
# PctBachDeg18_24                0.000000
# PctHS25_Over                   7.500000
# PctBachDeg25_Over              2.500000
# PctEmployed16_Over            22.037971
# PctUnemployed16_Over           0.500000
# PctPrivateCoverage            23.400000
# PctPrivateCoverageAlone       16.800000
# ...

# %%
pd.DataFrame.mean(training_data)
# Out:
# id                           2509.000000
# avgAnnCount                   593.163643
# avgDeathsPerYear              189.357785
# incidenceRate                 448.405713
# medIncome                   46964.295735
# popEst2015                 104498.025409
# povertyPercent                 16.951361
# studyPerCap                   140.121925
# MedianAge                      40.756753
# MedianAgeMale                  39.493247
# MedianAgeFemale                42.081383
# AvgHouseholdSize                2.480035
# PercentMarried                 51.671360
# PctNoHS18_24                   18.185923
# PctHS18_24                     35.057430
# PctSomeCol18_24                41.017916
# PctBachDeg18_24                 6.080604
# PctHS25_Over                   34.789425
# PctBachDeg25_Over              13.248320
# PctEmployed16_Over             54.061126
# PctUnemployed16_Over            7.892020
# PctPrivateCoverage             64.202327
# PctPrivateCoverageAlone        48.248320
# ...

# %%
pd.DataFrame.median(training_data)
# Out:
# id                          2509.000000
# avgAnnCount                  174.238108
# avgDeathsPerYear              62.806491
# incidenceRate                453.549422
# medIncome                  45110.356286
# popEst2015                 26971.670758
# povertyPercent                16.100000
# studyPerCap                    0.000000
# MedianAge                     40.831979
# MedianAgeMale                 39.500000
# MedianAgeFemale               42.300000
# AvgHouseholdSize               2.503888
# PercentMarried                52.175455
# PctNoHS18_24                  17.300000
# PctHS18_24                    34.748730
# PctSomeCol18_24               40.708668
# PctBachDeg18_24                5.351376
# PctHS25_Over                  35.239293
# PctBachDeg25_Over             12.382177
# PctEmployed16_Over            54.400000
# PctUnemployed16_Over           7.628695
# PctPrivateCoverage            64.900000
# PctPrivateCoverageAlone       48.420349
# ...

# %%
plt.figure()
for x in training_data:
    if x == "id":
        continue
    else:
        print(x)
        training_data[x].hist()
        plt.show()
# Out:
# avgAnnCount
# avgDeathsPerYear
# incidenceRate
# medIncome
# popEst2015
# povertyPercent
# studyPerCap
# MedianAge
# MedianAgeMale
# MedianAgeFemale
# AvgHouseholdSize
# PercentMarried
# PctNoHS18_24
# PctHS18_24
# PctSomeCol18_24
# PctBachDeg18_24
# PctHS25_Over
# PctBachDeg25_Over
# PctEmployed16_Over
# PctUnemployed16_Over
# PctPrivateCoverage
# PctPrivateCoverageAlone
# PctEmpPrivCoverage
# PctPublicCoverage
# PctPublicCoverageAlone
# PctWhite
# PctBlack
# PctAsian
# PctOtherRace
# PctMarriedHouseholds
# BirthRate
# TARGET_deathRate

# %%
plt.plot(training_data[x])
plt.show()
